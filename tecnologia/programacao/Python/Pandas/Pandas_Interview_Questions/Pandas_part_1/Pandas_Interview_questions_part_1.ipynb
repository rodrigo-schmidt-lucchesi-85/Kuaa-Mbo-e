# %% [markdown]
# # Pandas Interview Questions

# %% [markdown]
# In this tutorial's approach will be on Pandas-Python Interview Questions. If you are getting to be hired as Data Scientist or Data Engineer to be working with Pandas through the ETL process, some questions could be asked from your interviewer to ensure you are capable of handling dynamic tasks with Pandas.
#
# Nonetheless Pandas is one of the best Python Libraries or even on any programming language to perform data analysis or data manipulation.
# This tutorial will be followed by 40 questions from:
#
# They were adapted and described with more details.

# %% [markdown]
# ---
# 1) Define the Pandas/Python pandas?
#
# R.: From the source https://pandas.pydata.org/:
#
# "... Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,built on top of the Python programming language."
#
# Pandas dataframe strcuture performs similar to Excel spredsheets to help you out with automatization tasks over some collected data.
#
# Example:

# %%
# Defining data to the example
data = {'data':[[ 5, 20, 25, 0],[10, 24,  25, 1],[15, 22, 26, 0],[20,  21, 23,  1]],
        'target': [25, 23, 28, 0],
        'feature_names': ['month_day','indoor_temperature','outdoor_temperature','ar_conditioner_state'],
        'DESCR': 'This a sample dataset for lecturing purposes to answer the mentioned questions above'}

# %% [markdown]
# That's a dataset defined as dictionary. Each key represents a part to the present dataset. On this one a simulation to catch a restaurant thermodymics is represented with 4 features:
#
# - 'month_day'
# - 'indoor_temperature'
# - 'outdoor_temperature'
# - 'ar_conditioner_state'

# %%
# Importing library
import pandas

# %% [markdown]
# That's the part where we import Pandas to be used in our code

# %%
# Defining Pandas DataFrame
matrix_or_matrix_or_pandas_data_frame = pandas.DataFrame(data=data['data'],columns=data['feature_names'])
display(matrix_or_matrix_or_pandas_data_frame)
# Out:
#    month_day  indoor_temperature  outdoor_temperature  ar_conditioner_state
# 0          5                  20                   25                     0
# 1         10                  24                   25                     1
# 2         15                  22                   26                     0
# 3         20                  21                   23                     1

# %% [markdown]
# On this cell we're creating a Pandas dataframe, probably the most known Pandas data structure.

# %%
print(matrix_or_matrix_or_pandas_data_frame['indoor_temperature'].mean())
# Out:
# 21.75

# %% [markdown]
# Finally using one of many mathematical methods embedded on Pandas Library (mean())

# %% [markdown]
# ---

# %% [markdown]
# 2) Mention the different types of Data Structures in Pandas?
#
# R.: There are two main types of data structures in Pandas:
#
# 1 - Series: It behaves as column of a pandas dataframe. For who are familiar with algebra, it's a vector composing of diferent states.
#
#  Series = pandas.Series(data=None, index=None, dtype=None, name=None, copy=False, fastpath=False)
#
# 2 - DataFrame: It is a matrix, however called in Pandas as DataFrame because you can change data from the matrxi directly as spredsheets in excel for example.
#
#  Dataframe=  pandas.DataFrame(data=None, index: Optional[Collection] = None, columns: Optional[Collection] = None, dtype: Union[str, numpy.dtype, ExtensionDtype, None] = None, copy: bool = False)
#
# Example:

# %%
# from the dataset above:
dataframe = pandas.DataFrame(data=data['data'],columns=data['feature_names'])
display(dataframe)
display(dataframe.shape)
# Out:
#    month_day  indoor_temperature  outdoor_temperature  ar_conditioner_state
# 0          5                  20                   25                     0
# 1         10                  24                   25                     1
# 2         15                  22                   26                     0
# 3         20                  21                   23                     1
# (4, 4)

# %% [markdown]
# We're using the same datafram explicited above. Where getting the dataframe shape to check how Pandas dataframe is really a matrix compose by nxm dimensionsions.

# %%
# from the dataset above:
series = pandas.Series(data=dataframe['outdoor_temperature'],name='outdoor_temperature')
display(series)
display(series.shape)
# Out:
# 0    25
# 1    25
# 2    26
# 3    23
# Name: outdoor_temperature, dtype: int64
# (4,)

# %% [markdown]
# At this part, we're getting Pandas dataframe collumn, which are called Pandas series. This series could be a time series like this example, where continous values are collected from a especific sensor.

# %% [markdown]
# ---

# %% [markdown]
# 3) Define Series in Pandas?
#
# R.: Series is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.). The axis labels are collectively referred to as the index. The basic method to create a Series is to call:
#
# s = pd.Series(data, index=index)
#
# So series behave as a vector, with diferent states mesured or collected automatically or manually.
#
# Example:

# %%
import numpy as np
import matplotlib.pyplot as plt 
speed = (np.random.randint(70,80,(1,300)))
time_series = pandas.Series(data=speed[0],name = 'cars_speed')

_=plt.figure(num=None, figsize=(20, 5), dpi=100,facecolor='w', edgecolor='k')
_=time_series.plot(marker='o',legend=True)
_=plt.grid(True)
_=plt.xlabel('time (m)')
_=plt.ylabel('speed (km/h)')
_=plt.title("Data collected on a discrete interval of 1 minute from an electric vehicle's speed")
_=plt.show()

# %% [markdown]
# This example is common representation os a time series, commonly collected from sensors on some automated devices. So a Pandas Series are states collected on a determine discrete period and represented in machine learning for example each state as an instance.

# %% [markdown]
# ---

# %% [markdown]
# 4) How can we calculate the standard deviation from the Series?
#
# R.: Equation standard deviation
#
# Standard deviation are the aceptable limits to the state measure. It is related to a error having an anchor the mean valeu from the population or sample.
#
# Example:
#
# So we have a time series representing a sample from a power measure:
#
# Power = [84, 83, 85, 85, 82, 98, 91, 93, 89, 96, 96, 95, 87, 94, 86, 94, 96, 93, 91, 84]
#
# The standard deviation on pandas can be calculated as:

# %%
power = pandas.Series(data = list((np.random.randint(80,100,(1,100)))[0]),name='Electric Power')

# %%
standard_deviation = power.std()
mean = power.mean()
std_minus = mean - standard_deviation
std_max = mean + standard_deviation
lower_bound = power.min()
upper_bound = power.max()
print(f'STD valeu: +- {standard_deviation}')
print(f'MEAN valeu: {mean}')
# Out:
# STD valeu: +- 6.294867237309578
# MEAN valeu: 90.03

# %%
import numpy as np
from scipy.interpolate import interp1d
import seaborn as sns
_= plt.figure(num=None, figsize=(15, 5), dpi=100, facecolor='w', edgecolor='k')
ax = sns.kdeplot(power,shade=True)
line = ax.lines[0].get_data()
ipf = interp1d(x=line[0], y=line[1])
stdmin= ax.plot([std_minus, std_minus], [0, ipf(std_minus)],'r--',label='std -',linewidth=1)
stdmax= ax.plot([std_max, std_max], [0, ipf(std_max)],'y--',label='std +',linewidth=1)
meanval= ax.plot([mean, mean], [0, ipf(mean)],'g-',label='mean value',linewidth=3)
_= plt.title('Statistic metrics for collected Electric Power')
_= ax.grid(True)
_= ax.legend()

# %% [markdown]
# At this plot we're representing the Pandas Series and the two metrics calculated (standard deviation and mean value)

# %% [markdown]
# 5) Define DataFrame in Pandas?
#
# Answer:
#
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object. Like Series, DataFrame accepts many different kinds of input:
#
#     Dict of 1D ndarrays, lists, dicts, or Series
#
#     2-D numpy.ndarray
#
#     Structured or record ndarray
#
#     A Series
#
#     Another DataFrame
#
# Example:

# %%
d = {'one': pandas.Series([1., 2., 3., 5.], index=['a', 'b', 'c', 'd']),
     'two': pandas.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}

# %%
#From dict of Series or dicts

df = pandas.DataFrame(d)
display(df)
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  5.0  4.0

# %%
# From dict of ndarrays / lists

d = {'one': [1., 2., 3., 4.],
     'two': [4., 3., 2., 1.]}
display(pandas.DataFrame(d))
# Out:
#    one  two
# 0  1.0  4.0
# 1  2.0  3.0
# 2  3.0  2.0
# 3  4.0  1.0

# %%
# From a list of dicts

data2 = [{'a': 1, 'b': 2}, {'a': 5, 'b': 10, 'c': 20}]
display(pandas.DataFrame(data2))
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
# From a dict of Tuples
display(pandas.DataFrame({('a', 'b'): {('A', 'B'): 1, ('A', 'C'): 2},
                  ('a', 'a'): {('A', 'C'): 3, ('A', 'B'): 4},
                  ('a', 'c'): {('A', 'B'): 5, ('A', 'C'): 6},
                  ('b', 'a'): {('A', 'C'): 7, ('A', 'B'): 8},
                  ('b', 'b'): {('A', 'D'): 9, ('A', 'B'): 10}}))
# Out:
#        a              b
#        b    a    c    a     b
# A B  1.0  4.0  5.0  8.0  10.0
#   C  2.0  3.0  6.0  7.0   NaN
#   D  NaN  NaN  NaN  NaN   9.0

# %%
# From a series
  
author = ['João', 'Paulo', 'Manuela', 'Laura'] 
article = [210, 211, 114, 178] 
  
auth_series = pandas.Series(author) 
article_series = pandas.Series(article) 
  
frame = { 'Author': auth_series, 'Article': article_series } 
  
result = pandas.DataFrame(frame) 
  
display(result)
# Out:
#     Author  Article
# 0     João      210
# 1    Paulo      211
# 2  Manuela      114
# 3    Laura      178

# %%
# From another DataFrame
df1 = pandas.DataFrame(np.random.randn(5,3), index=pandas.date_range('01/02/2014',periods=5,freq='D'), columns=['a','b','c'] )
df2 = pandas.DataFrame(np.random.randn(8,3), index=pandas.date_range('01/01/2014',periods=8,freq='D'), columns=['a','b','c'] )

# Create an index list from the set of dates in both data frames
Index = list(set(list(df1.index) + list(df2.index)))
Index.sort()

df3 = pandas.DataFrame({'df1': [df1.loc[Date, 'c'] if Date in df1.index else np.nan for Date in Index],\
                'df2': [df2.loc[Date, 'c'] if Date in df2.index else np.nan for Date in Index],},\
                index = Index)

display(df3)
# Out:
#                  df1       df2
# 2014-01-01       NaN  0.591620
# 2014-01-02 -0.548076  0.951981
# 2014-01-03  0.551082 -0.023889
# 2014-01-04 -0.365452 -0.749270
# 2014-01-05  0.336783  0.237968
# 2014-01-06 -0.634168  0.401509
# 2014-01-07       NaN  0.204292
# 2014-01-08       NaN -0.828170
